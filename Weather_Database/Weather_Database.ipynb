# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np# Import the API key.

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citpy dependency
from citipy import citipy

# %%
# Create a lis for holding the cities
cities = []

# Identify nearest city for each long/lat combination
for coordinate in coordinates :
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #If city is unique, add it to cities list
    if city not in cities :
        cities.append(city)
        
# Count city list
len(cities)
# Out:
# 756

# %%
# Import requests libary
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Create an endpoint URL for a city.
        city_url = url + "&q=" + city.replace(" ","+")

        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]      
        city_weather_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
#                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | anadyr
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | olga
# Processing Record 6 of Set 1 | chimoio
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | pasni
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | anloga
# Processing Record 12 of Set 1 | luwuk
# Processing Record 13 of Set 1 | rosetta
# Processing Record 14 of Set 1 | broome
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | husavik
# Processing Record 17 of Set 1 | buckingham
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | hofn
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | tungor
# Processing Record 24 of Set 1 | vostok
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | acapulco
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | kainantu
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | gouyave
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | mugur-aksy
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | shelburne
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | sarakhs
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | ponta do sol
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | mountain home
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | ixtapa
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | muroto
# Processing Record 50 of Set 1 | lianran
# Processing Record 1 of Set 2 | manta
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | dedza
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | dabat
# Processing Record 6 of Set 2 | jizan
# Processing Record 7 of Set 2 | ewa beach
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 2 | ahipara
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | talagang
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | cooma
# Processing Record 17 of Set 2 | praia da vitoria
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | brigantine
# Processing Record 21 of Set 2 | tura
# Processing Record 22 of Set 2 | sokolskoye
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | shitanjing
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | mattru
# Processing Record 27 of Set 2 | mihijam
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | codrington
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | manzhouli
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 2 | dunedin
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | nakamura
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | atar
# Processing Record 44 of Set 2 | brewster
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | tarauaca
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | quatre cocos
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | kourou
# Processing Record 2 of Set 3 | kermanshah
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | lagoa
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | zhigansk
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | warrnambool
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | kashi
# Processing Record 14 of Set 3 | kahramanmaras
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 3 | dinga
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | fredericksburg
# Processing Record 21 of Set 3 | los llanos de aridane
# Processing Record 22 of Set 3 | sorland
# Processing Record 23 of Set 3 | chico
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | kharp
# Processing Record 26 of Set 3 | jacareacanga
# Processing Record 27 of Set 3 | sompeta
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | estelle
# Processing Record 30 of Set 3 | dwarka
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | avera
# Processing Record 33 of Set 3 | elayirampannai
# Processing Record 34 of Set 3 | sao miguel do araguaia
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | grand gaube
# Processing Record 37 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 3 | cartagena
# Processing Record 39 of Set 3 | marawi
# Processing Record 40 of Set 3 | rio verde de mato grosso
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 3 | siocon
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | balkhash
# Processing Record 46 of Set 3 | tigil
# Processing Record 47 of Set 3 | emba
# Processing Record 48 of Set 3 | saint anthony
# Processing Record 49 of Set 3 | mazyr
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | baijiantan
# Processing Record 2 of Set 4 | skelleftea
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | kyzyl-mazhalyk
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | valverde del camino
# Processing Record 12 of Set 4 | paamiut
# Processing Record 13 of Set 4 | birao
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | meadow lake
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | izhmorskiy
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | porto novo
# Processing Record 23 of Set 4 | praya
# Processing Record 24 of Set 4 | copperas cove
# Processing Record 25 of Set 4 | kyren
# Processing Record 26 of Set 4 | matagami
# Processing Record 27 of Set 4 | bowmore
# Processing Record 28 of Set 4 | bandarbeyla
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | ust-ilimsk
# Processing Record 32 of Set 4 | santa rosa
# Processing Record 33 of Set 4 | comodoro rivadavia
# Processing Record 34 of Set 4 | egvekinot
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | tulun
# Processing Record 37 of Set 4 | atlantic city
# Processing Record 38 of Set 4 | mackay
# Processing Record 39 of Set 4 | kanye
# Processing Record 40 of Set 4 | lebyazhye
# Processing Record 41 of Set 4 | liverpool
# Processing Record 42 of Set 4 | moranbah
# Processing Record 43 of Set 4 | marienburg
# Processing Record 44 of Set 4 | nabire
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | batagay-alyta
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 4 | antalaha
# Processing Record 49 of Set 4 | toora-khem
# Processing Record 50 of Set 4 | okhotsk
# Processing Record 1 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | henties bay
# Processing Record 5 of Set 5 | balykshi
# Processing Record 6 of Set 5 | aguimes
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | osorno
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | tuatapere
# Processing Record 13 of Set 5 | kondinskoye
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | hirara
# Processing Record 16 of Set 5 | antofagasta
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | pombal
# Processing Record 19 of Set 5 | cleveland
# Processing Record 20 of Set 5 | ust-kuyga
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | dubbo
# Processing Record 23 of Set 5 | vanavara
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | qingdao
# Processing Record 26 of Set 5 | leiyang
# Processing Record 27 of Set 5 | vilyuysk
# Processing Record 28 of Set 5 | ostrovnoy
# Processing Record 29 of Set 5 | port lincoln
# Processing Record 30 of Set 5 | pangkalanbuun
# Processing Record 31 of Set 5 | marondera
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | huilong
# Processing Record 34 of Set 5 | brae
# Processing Record 35 of Set 5 | zhanaozen
# Processing Record 36 of Set 5 | meulaboh
# Processing Record 37 of Set 5 | buraydah
# Processing Record 38 of Set 5 | cachoeiras de macacu
# Processing Record 39 of Set 5 | wanxian
# Processing Record 40 of Set 5 | artigas
# Processing Record 41 of Set 5 | kropotkin
# Processing Record 42 of Set 5 | vaasa
# Processing Record 43 of Set 5 | yulara
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | senador canedo
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | kirakira
# Processing Record 48 of Set 5 | saint george
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | yadgir
# Processing Record 1 of Set 6 | mount isa
# Processing Record 2 of Set 6 | yermakovskoye
# Processing Record 3 of Set 6 | port hedland
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | rockhampton
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | jesup
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | north platte
# Processing Record 10 of Set 6 | san borja
# Processing Record 11 of Set 6 | yuli
# Processing Record 12 of Set 6 | palaikastron
# Processing Record 13 of Set 6 | maralal
# Processing Record 14 of Set 6 | nalut
# Processing Record 15 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 6 | ewo
# Processing Record 17 of Set 6 | berlevag
# Processing Record 18 of Set 6 | camacha
# Processing Record 19 of Set 6 | parga
# Processing Record 20 of Set 6 | khatanga
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | richard toll
# City not found. Skipping...
# Processing Record 23 of Set 6 | coihaique
# Processing Record 24 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 6 | qasigiannguit
# Processing Record 26 of Set 6 | bukachacha
# Processing Record 27 of Set 6 | nhulunbuy
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | qaqortoq
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | bowen
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | were ilu
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | taihe
# Processing Record 38 of Set 6 | komsomolskiy
# Processing Record 39 of Set 6 | lishui
# Processing Record 40 of Set 6 | ketchikan
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | skjervoy
# Processing Record 43 of Set 6 | trollhattan
# Processing Record 44 of Set 6 | ndele
# Processing Record 45 of Set 6 | dotnuva
# Processing Record 46 of Set 6 | tirumullaivasal
# Processing Record 47 of Set 6 | botou
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 6 | merauke
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 3 of Set 7 | nanakuli
# Processing Record 4 of Set 7 | kalmunai
# Processing Record 5 of Set 7 | vardo
# Processing Record 6 of Set 7 | baykit
# Processing Record 7 of Set 7 | snasa
# Processing Record 8 of Set 7 | waw
# Processing Record 9 of Set 7 | yaring
# Processing Record 10 of Set 7 | madang
# Processing Record 11 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 7 | phibun mangsahan
# Processing Record 13 of Set 7 | saint-paul
# Processing Record 14 of Set 7 | bozova
# Processing Record 15 of Set 7 | praia
# Processing Record 16 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 7 | hailar
# Processing Record 18 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 7 | stavern
# Processing Record 20 of Set 7 | pangnirtung
# Processing Record 21 of Set 7 | manokwari
# Processing Record 22 of Set 7 | beitbridge
# Processing Record 23 of Set 7 | chara
# Processing Record 24 of Set 7 | tuktoyaktuk
# Processing Record 25 of Set 7 | gobabis
# Processing Record 26 of Set 7 | atbasar
# Processing Record 27 of Set 7 | yilan
# Processing Record 28 of Set 7 | khandyga
# Processing Record 29 of Set 7 | kontagora
# Processing Record 30 of Set 7 | pokanayevka
# City not found. Skipping...
# Processing Record 31 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 7 | gorontalo
# Processing Record 33 of Set 7 | raga
# Processing Record 34 of Set 7 | port elizabeth
# Processing Record 35 of Set 7 | plettenberg bay
# Processing Record 36 of Set 7 | vanimo
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | baturaja
# Processing Record 39 of Set 7 | hambantota
# Processing Record 40 of Set 7 | salym
# Processing Record 41 of Set 7 | mikropolis
# Processing Record 42 of Set 7 | singkawang
# Processing Record 43 of Set 7 | leningradskiy
# Processing Record 44 of Set 7 | cidreira
# Processing Record 45 of Set 7 | belmonte
# Processing Record 46 of Set 7 | bakel
# Processing Record 47 of Set 7 | santa cruz verapaz
# Processing Record 48 of Set 7 | port hardy
# Processing Record 49 of Set 7 | darhan
# Processing Record 50 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 8 | caxias
# Processing Record 2 of Set 8 | itarema
# Processing Record 3 of Set 8 | huarmey
# Processing Record 4 of Set 8 | caravelas
# Processing Record 5 of Set 8 | naryan-mar
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 8 | salcininkai
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | coronel martinez
# Processing Record 11 of Set 8 | guaramirim
# Processing Record 12 of Set 8 | high level
# Processing Record 13 of Set 8 | nizhniy kuranakh
# Processing Record 14 of Set 8 | lompoc
# Processing Record 15 of Set 8 | alice springs
# Processing Record 16 of Set 8 | camana
# Processing Record 17 of Set 8 | waipawa
# Processing Record 18 of Set 8 | banjar
# Processing Record 19 of Set 8 | inuvik
# Processing Record 20 of Set 8 | sovata
# Processing Record 21 of Set 8 | kattivakkam
# Processing Record 22 of Set 8 | yagodnoye
# Processing Record 23 of Set 8 | pochutla
# Processing Record 24 of Set 8 | marsh harbour
# Processing Record 25 of Set 8 | samarai
# Processing Record 26 of Set 8 | samana
# Processing Record 27 of Set 8 | khvalynsk
# Processing Record 28 of Set 8 | amapa
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | coari
# Processing Record 31 of Set 8 | yining
# Processing Record 32 of Set 8 | bachaquero
# Processing Record 33 of Set 8 | korla
# Processing Record 34 of Set 8 | ramhormoz
# Processing Record 35 of Set 8 | ca mau
# Processing Record 36 of Set 8 | santa cruz
# Processing Record 37 of Set 8 | tautira
# Processing Record 38 of Set 8 | ravar
# Processing Record 39 of Set 8 | cascais
# Processing Record 40 of Set 8 | moron
# Processing Record 41 of Set 8 | victor harbor
# Processing Record 42 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 8 | qinhuangdao
# Processing Record 44 of Set 8 | piacabucu
# Processing Record 45 of Set 8 | vanderhoof
# Processing Record 46 of Set 8 | gat
# Processing Record 47 of Set 8 | morondava
# Processing Record 48 of Set 8 | prince rupert
# Processing Record 49 of Set 8 | nelson bay
# Processing Record 50 of Set 8 | halifax
# Processing Record 1 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 9 | hobyo
# Processing Record 3 of Set 9 | karamken
# City not found. Skipping...
# Processing Record 4 of Set 9 | marmaris
# Processing Record 5 of Set 9 | clyde river
# Processing Record 6 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 9 | sobolevo
# Processing Record 9 of Set 9 | nouakchott
# Processing Record 10 of Set 9 | mporokoso
# Processing Record 11 of Set 9 | srostki
# Processing Record 12 of Set 9 | copala
# Processing Record 13 of Set 9 | severo-kurilsk
# Processing Record 14 of Set 9 | krasnoselkup
# Processing Record 15 of Set 9 | rio gallegos
# Processing Record 16 of Set 9 | malisbong
# City not found. Skipping...
# Processing Record 17 of Set 9 | olafsvik
# Processing Record 18 of Set 9 | tecoanapa
# Processing Record 19 of Set 9 | doha
# Processing Record 20 of Set 9 | maceio
# Processing Record 21 of Set 9 | uralskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | dingle
# Processing Record 23 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 9 | mstera
# Processing Record 25 of Set 9 | cozumel
# Processing Record 26 of Set 9 | ternate
# Processing Record 27 of Set 9 | cap malheureux
# Processing Record 28 of Set 9 | erenhot
# Processing Record 29 of Set 9 | rocha
# Processing Record 30 of Set 9 | inta
# Processing Record 31 of Set 9 | blue springs
# Processing Record 32 of Set 9 | nebolchi
# Processing Record 33 of Set 9 | hami
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 9 | cabra
# Processing Record 37 of Set 9 | adeje
# Processing Record 38 of Set 9 | kemijarvi
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | emilio carranza
# Processing Record 41 of Set 9 | vzmorye
# Processing Record 42 of Set 9 | kemin
# Processing Record 43 of Set 9 | malanje
# Processing Record 44 of Set 9 | omegna
# Processing Record 45 of Set 9 | xitla
# City not found. Skipping...
# Processing Record 46 of Set 9 | porosozero
# Processing Record 47 of Set 9 | broken hill
# Processing Record 48 of Set 9 | mayahi
# Processing Record 49 of Set 9 | maine-soroa
# Processing Record 50 of Set 9 | beaufort
# Processing Record 1 of Set 10 | vung tau
# Processing Record 2 of Set 10 | kieta
# Processing Record 3 of Set 10 | canutama
# Processing Record 4 of Set 10 | matara
# Processing Record 5 of Set 10 | leshukonskoye
# Processing Record 6 of Set 10 | puerto el triunfo
# Processing Record 7 of Set 10 | haines junction
# Processing Record 8 of Set 10 | sampit
# Processing Record 9 of Set 10 | loandjili
# Processing Record 10 of Set 10 | masuguru
# Processing Record 11 of Set 10 | gravelbourg
# Processing Record 12 of Set 10 | tagcatong
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | jacobina
# Processing Record 15 of Set 10 | chivay
# Processing Record 16 of Set 10 | shizunai
# Processing Record 17 of Set 10 | nyurba
# Processing Record 18 of Set 10 | homer
# Processing Record 19 of Set 10 | the pas
# Processing Record 20 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 10 | iranshahr
# Processing Record 22 of Set 10 | roald
# Processing Record 23 of Set 10 | muswellbrook
# Processing Record 24 of Set 10 | stornoway
# Processing Record 25 of Set 10 | sao jose da coroa grande
# Processing Record 26 of Set 10 | nishihara
# Processing Record 27 of Set 10 | biak
# Processing Record 28 of Set 10 | ayan
# Processing Record 29 of Set 10 | payakumbuh
# Processing Record 30 of Set 10 | balabac
# Processing Record 31 of Set 10 | bardiyah
# Processing Record 32 of Set 10 | fairbanks
# Processing Record 33 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 10 | tabuk
# Processing Record 35 of Set 10 | rabo de peixe
# Processing Record 36 of Set 10 | harper
# Processing Record 37 of Set 10 | tianpeng
# Processing Record 38 of Set 10 | omsukchan
# Processing Record 39 of Set 10 | teya
# Processing Record 40 of Set 10 | gigmoto
# Processing Record 41 of Set 10 | biaora
# Processing Record 42 of Set 10 | shirvan
# Processing Record 43 of Set 10 | tymovskoye
# Processing Record 44 of Set 10 | murray bridge
# Processing Record 45 of Set 10 | seymchan
# Processing Record 46 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 10 | kamaishi
# Processing Record 48 of Set 10 | volga
# Processing Record 49 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 10 | quesnel
# Processing Record 1 of Set 11 | conde
# Processing Record 2 of Set 11 | yamada
# Processing Record 3 of Set 11 | muros
# Processing Record 4 of Set 11 | boa vista
# Processing Record 5 of Set 11 | trinidad
# Processing Record 6 of Set 11 | ribeira grande
# Processing Record 7 of Set 11 | pacifica
# Processing Record 8 of Set 11 | ailigandi
# Processing Record 9 of Set 11 | udachnyy
# Processing Record 10 of Set 11 | fort nelson
# Processing Record 11 of Set 11 | safranbolu
# Processing Record 12 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 13 of Set 11 | bauru
# Processing Record 14 of Set 11 | aklavik
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | stroby egede
# Processing Record 17 of Set 11 | hualmay
# Processing Record 18 of Set 11 | kisangani
# Processing Record 19 of Set 11 | pyaozerskiy
# Processing Record 20 of Set 11 | poronaysk
# Processing Record 21 of Set 11 | semey
# Processing Record 22 of Set 11 | banda aceh
# Processing Record 23 of Set 11 | gravdal
# Processing Record 24 of Set 11 | ballina
# Processing Record 25 of Set 11 | hamilton
# Processing Record 26 of Set 11 | gazojak
# Processing Record 27 of Set 11 | soure
# Processing Record 28 of Set 11 | phan thiet
# Processing Record 29 of Set 11 | mandalgovi
# Processing Record 30 of Set 11 | senno
# Processing Record 31 of Set 11 | shingu
# Processing Record 32 of Set 11 | katsuura
# Processing Record 33 of Set 11 | sao domingos do maranhao
# Processing Record 34 of Set 11 | pinega
# Processing Record 35 of Set 11 | khash
# Processing Record 36 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 11 | sexsmith
# Processing Record 38 of Set 11 | spremberg
# Processing Record 39 of Set 11 | bonthe
# Processing Record 40 of Set 11 | capaci
# Processing Record 41 of Set 11 | la ronge
# Processing Record 42 of Set 11 | namibe
# Processing Record 43 of Set 11 | margate
# Processing Record 44 of Set 11 | presidencia roque saenz pena
# Processing Record 45 of Set 11 | chiclana
# Processing Record 46 of Set 11 | poopo
# Processing Record 47 of Set 11 | owo
# Processing Record 48 of Set 11 | mount pleasant
# Processing Record 49 of Set 11 | villanueva de la serena
# Processing Record 50 of Set 11 | betare oya
# Processing Record 1 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 12 | eureka
# Processing Record 3 of Set 12 | peachland
# Processing Record 4 of Set 12 | neuquen
# Processing Record 5 of Set 12 | barra da estiva
# Processing Record 6 of Set 12 | hervey bay
# Processing Record 7 of Set 12 | hurricane
# Processing Record 8 of Set 12 | birin
# Processing Record 9 of Set 12 | ulaangom
# Processing Record 10 of Set 12 | saint-joseph
# Processing Record 11 of Set 12 | alta floresta
# Processing Record 12 of Set 12 | calimete
# Processing Record 13 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 12 | san quintin
# Processing Record 15 of Set 12 | altamont
# Processing Record 16 of Set 12 | vao
# Processing Record 17 of Set 12 | ossora
# Processing Record 18 of Set 12 | nha trang
# Processing Record 19 of Set 12 | penzance
# Processing Record 20 of Set 12 | vilhena
# Processing Record 21 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 12 | dongsheng
# Processing Record 23 of Set 12 | aksehir
# Processing Record 24 of Set 12 | varzea grande
# Processing Record 25 of Set 12 | christchurch
# Processing Record 26 of Set 12 | medicine hat
# Processing Record 27 of Set 12 | amahai
# Processing Record 28 of Set 12 | jaguaribe
# Processing Record 29 of Set 12 | taltal
# Processing Record 30 of Set 12 | groningen
# Processing Record 31 of Set 12 | rusape
# Processing Record 32 of Set 12 | pedernales
# Processing Record 33 of Set 12 | flin flon
# Processing Record 34 of Set 12 | menongue
# Processing Record 35 of Set 12 | lyaskelya
# Processing Record 36 of Set 12 | mercedes
# Processing Record 37 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 12 | show low
# Processing Record 39 of Set 12 | narasannapeta
# Processing Record 40 of Set 12 | zabaykalsk
# Processing Record 41 of Set 12 | belyy yar
# Processing Record 42 of Set 12 | katherine
# Processing Record 43 of Set 12 | ornskoldsvik
# Processing Record 44 of Set 12 | lazarev
# Processing Record 45 of Set 12 | berdigestyakh
# Processing Record 46 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | arlit
# Processing Record 48 of Set 12 | half moon bay
# Processing Record 49 of Set 12 | oranjestad
# Processing Record 50 of Set 12 | balclutha
# Processing Record 1 of Set 13 | nokha
# Processing Record 2 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 13 | east london
# Processing Record 4 of Set 13 | yerofey pavlovich
# Processing Record 5 of Set 13 | oktyabrskoye
# Processing Record 6 of Set 13 | bull savanna
# Processing Record 7 of Set 13 | bar harbor
# Processing Record 8 of Set 13 | coreau
# Processing Record 9 of Set 13 | san lazaro
# Processing Record 10 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 13 | tiznit
# Processing Record 12 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 13 | inirida
# Processing Record 14 of Set 13 | portlethen
# Processing Record 15 of Set 13 | cockburn town
# Processing Record 16 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 17 of Set 13 | reguengos de monsaraz
# Processing Record 18 of Set 13 | rudnya
# Processing Record 19 of Set 13 | joliette
# Processing Record 20 of Set 13 | methoni
# Processing Record 21 of Set 13 | lasem
# Processing Record 22 of Set 13 | lodja
# Processing Record 23 of Set 13 | lake havasu city
# Processing Record 24 of Set 13 | parfino
# Processing Record 25 of Set 13 | kavieng
# Processing Record 26 of Set 13 | salobrena
# Processing Record 27 of Set 13 | hurghada
# Processing Record 28 of Set 13 | salalah
# Processing Record 29 of Set 13 | buchanan
# Processing Record 30 of Set 13 | tommot
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | ferma
# Processing Record 33 of Set 13 | lazaro cardenas
# Processing Record 34 of Set 13 | muhos
# Processing Record 35 of Set 13 | kavaratti
# Processing Record 36 of Set 13 | kigoma
# Processing Record 37 of Set 13 | kloulklubed
# Processing Record 38 of Set 13 | andra
# Processing Record 39 of Set 13 | columbus
# Processing Record 40 of Set 13 | shimanovsk
# Processing Record 41 of Set 13 | kirovsk
# Processing Record 42 of Set 13 | moses lake
# Processing Record 43 of Set 13 | dandong
# Processing Record 44 of Set 13 | koupela
# Processing Record 45 of Set 13 | balikpapan
# Processing Record 46 of Set 13 | nkayi
# Processing Record 47 of Set 13 | panjab
# Processing Record 48 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 13 | sabang
# Processing Record 50 of Set 13 | teguise
# Processing Record 1 of Set 14 | martapura
# Processing Record 2 of Set 14 | alekseyevka
# Processing Record 3 of Set 14 | necochea
# Processing Record 4 of Set 14 | yerbogachen
# Processing Record 5 of Set 14 | richmond
# Processing Record 6 of Set 14 | kinlochleven
# Processing Record 7 of Set 14 | kamennomostskiy
# Processing Record 8 of Set 14 | caluquembe
# Processing Record 9 of Set 14 | jati
# Processing Record 10 of Set 14 | fort-shevchenko
# Processing Record 11 of Set 14 | sistranda
# Processing Record 12 of Set 14 | thunder bay
# Processing Record 13 of Set 14 | iquitos
# Processing Record 14 of Set 14 | bayanday
# Processing Record 15 of Set 14 | vezirkopru
# Processing Record 16 of Set 14 | santiago de cao
# Processing Record 17 of Set 14 | pavilosta
# Processing Record 18 of Set 14 | bolshevik
# Processing Record 19 of Set 14 | asau
# Processing Record 20 of Set 14 | winchester
# Processing Record 21 of Set 14 | sur
# Processing Record 22 of Set 14 | ust-nera
# Processing Record 23 of Set 14 | bayir
# Processing Record 24 of Set 14 | baranoa
# Processing Record 25 of Set 14 | talisay
# Processing Record 26 of Set 14 | kankan
# Processing Record 27 of Set 14 | bima
# Processing Record 28 of Set 14 | churapcha
# Processing Record 29 of Set 14 | kuryk
# Processing Record 30 of Set 14 | tezu
# Processing Record 31 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 14 | sorochinsk
# Processing Record 33 of Set 14 | brinkovskaya
# Processing Record 34 of Set 14 | alyangula
# Processing Record 35 of Set 14 | tupik
# Processing Record 36 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 14 | laguna
# Processing Record 38 of Set 14 | ormara
# Processing Record 39 of Set 14 | mao
# Processing Record 40 of Set 14 | brandys nad labem-stara boleslav
# Processing Record 41 of Set 14 | juarez
# Processing Record 42 of Set 14 | tsabong
# Processing Record 43 of Set 14 | trairi
# Processing Record 44 of Set 14 | tutoia
# Processing Record 45 of Set 14 | buala
# Processing Record 46 of Set 14 | betioky
# Processing Record 47 of Set 14 | sanary-sur-mer
# Processing Record 48 of Set 14 | padang
# Processing Record 49 of Set 14 | escanaba
# Processing Record 50 of Set 14 | college
# Processing Record 1 of Set 15 | larreynaga
# Processing Record 2 of Set 15 | devonport
# Processing Record 3 of Set 15 | camocim
# Processing Record 4 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 15 | joetsu
# Processing Record 6 of Set 15 | najran
# Processing Record 7 of Set 15 | namatanai
# Processing Record 8 of Set 15 | tono
# Processing Record 9 of Set 15 | oyotun
# Processing Record 10 of Set 15 | puerto del rosario
# Processing Record 11 of Set 15 | zamosc
# Processing Record 12 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 15 | yangambi
# Processing Record 14 of Set 15 | la carolina
# Processing Record 15 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 16 of Set 15 | atikokan
# Processing Record 17 of Set 15 | termiz
# Processing Record 18 of Set 15 | zuwarah
# Processing Record 19 of Set 15 | carauari
# Processing Record 20 of Set 15 | culaman
# Processing Record 21 of Set 15 | wanderlandia
# City not found. Skipping...
# Processing Record 22 of Set 15 | aquiraz
# Processing Record 23 of Set 15 | richards bay
# Processing Record 24 of Set 15 | kenda
# Processing Record 25 of Set 15 | bambanglipuro
# Processing Record 26 of Set 15 | hawalli
# Processing Record 27 of Set 15 | axim
# Processing Record 28 of Set 15 | svetlogorsk
# Processing Record 29 of Set 15 | qeshm
# Processing Record 30 of Set 15 | ridgecrest
# Processing Record 31 of Set 15 | colquechaca
# Processing Record 32 of Set 15 | leh
# Processing Record 33 of Set 15 | dhidhdhoo
# Processing Record 34 of Set 15 | aviles
# Processing Record 35 of Set 15 | san francisco del mar
# Processing Record 36 of Set 15 | lata
# Processing Record 37 of Set 15 | bouar
# Processing Record 38 of Set 15 | dire
# Processing Record 39 of Set 15 | visby
# Processing Record 40 of Set 15 | ingham
# Processing Record 41 of Set 15 | astana
# Processing Record 42 of Set 15 | gizo
# Processing Record 43 of Set 15 | domoni
# Processing Record 44 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 45 of Set 15 | kaeo
# Processing Record 46 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 15 | talcahuano
# Processing Record 48 of Set 15 | arman
# Processing Record 49 of Set 15 | kirkconnel
# Processing Record 50 of Set 15 | portland
# Processing Record 1 of Set 16 | tromso
# Processing Record 2 of Set 16 | san bartolome de tirajana
# Processing Record 3 of Set 16 | marzuq
# Processing Record 4 of Set 16 | lunenburg
# Processing Record 5 of Set 16 | fenoarivo
# Processing Record 6 of Set 16 | nicoya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add weather data to a new Data Frame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Jamestown      US  42.0970  -79.2353     31.51        79         100
# 1     Anadyr      RU  64.7500  177.4833     27.10       100          75
# 2    Rikitea      PF -23.1203 -134.9692     74.07        89         100
# 3       Olga      RU  43.7444  135.2892     36.12        65          13
# 4    Chimoio      MZ -19.1164   33.4833     75.06        69          20
#
#    Wind Speed Current Description
# 0       14.97                mist
# 1        6.71       broken clouds
# 2       20.78       moderate rain
# 3        3.78          few clouds
# 4        4.38          few clouds

# %%
# Export data frame as WeatherPy_Database.csv into Weather_Database folder
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
